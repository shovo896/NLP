# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm
import tensorflow as tf 
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,Conv1D,GlobalMaxPooling1D,Dense,Dropout
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing import sequence

# %%
vocab_size=10000
max_length=500
(x_train,y_train),(x_test,y_test)=imdb.load_data(num_words=vocab_size)
x_train=sequence.pad_sequences(x_train,maxlen=max_length)
x_test=sequence.pad_sequences(x_test,maxlen=max_length)

# %% [markdown]
# building CNN model

# %%
model=Sequential([
    Embedding(vocab_size,100,input_length=max_length),
    Conv1D(128,5,activation='relu'),
    GlobalMaxPooling1D(),
    Dense(64,activation='relu'),
    Dropout(0.5),
    Dense(1,activation='sigmoid')
])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/keras/src/layers/core/embedding.py:97: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=5,batch_size=64,validation_split=0.2)
# Out:
# Epoch 1/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 24s 72ms/step - accuracy: 0.7395 - loss: 0.4967 - val_accuracy: 0.8624 - val_loss: 0.3239
# Epoch 2/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step - accuracy: 0.9078 - loss: 0.2383 - val_accuracy: 0.8956 - val_loss: 0.2601
# Epoch 3/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 71ms/step - accuracy: 0.9685 - loss: 0.1017 - val_accuracy: 0.8950 - val_loss: 0.2847
# Epoch 4/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step - accuracy: 0.9936 - loss: 0.0292 - val_accuracy: 0.8846 - val_loss: 0.3774
# Epoch 5/5
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 22s 72ms/step - accuracy: 0.9981 - loss: 0.0103 - val_accuracy: 0.8994 - val_loss: 0.3901

# %%
test_loss,test_acc=model.evaluate(x_test,y_test)
print('Test Accuracy:',test_acc)
# Out:
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step - accuracy: 0.8890 - loss: 0.4148
# Test Accuracy: 0.8890399932861328
