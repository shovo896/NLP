# %%
! pip install pytextrank
# Out:
# Collecting pytextrank
#   Downloading pytextrank-3.3.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: GitPython>=3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pytextrank) (3.1.46)
# Collecting graphviz>=0.13 (from pytextrank)
#   Downloading graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Collecting icecream>=2.1 (from pytextrank)
#   Downloading icecream-2.1.10-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: networkx>=2.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from networkx[default]>=2.6->pytextrank) (3.5)
# Requirement already satisfied: pygments>=2.7.4 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from pytextrank) (2.19.2)
# Requirement already satisfied: scipy>=1.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pytextrank) (1.11.4)
# Requirement already satisfied: spacy>=3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pytextrank) (3.8.11)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from GitPython>=3.1->pytextrank) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from gitdb<5,>=4.0.1->GitPython>=3.1->pytextrank) (5.0.2)
# Requirement already satisfied: colorama>=0.3.9 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from icecream>=2.1->pytextrank) (0.4.6)
# Requirement already satisfied: executing>=2.1.0 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from icecream>=2.1->pytextrank) (2.2.1)
# Requirement already satisfied: asttokens>=2.0.1 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from icecream>=2.1->pytextrank) (3.0.0)
# Requirement already satisfied: numpy>=1.25 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from networkx[default]>=2.6->pytextrank) (1.26.4)
# Requirement already satisfied: matplotlib>=3.8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from networkx[default]>=2.6->pytextrank) (3.8.4)
# Requirement already satisfied: pandas>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from networkx[default]>=2.6->pytextrank) (2.2.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.8->networkx[default]>=2.6->pytextrank) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.8->networkx[default]>=2.6->pytextrank) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.8->networkx[default]>=2.6->pytextrank) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.8->networkx[default]>=2.6->pytextrank) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from matplotlib>=3.8->networkx[default]>=2.6->pytextrank) (25.0)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.8->networkx[default]>=2.6->pytextrank) (12.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.8->networkx[default]>=2.6->pytextrank) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from matplotlib>=3.8->networkx[default]>=2.6->pytextrank) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=2.0->networkx[default]>=2.6->pytextrank) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas>=2.0->networkx[default]>=2.6->pytextrank) (2025.2)
# Requirement already satisfied: six>=1.5 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from python-dateutil>=2.7->matplotlib>=3.8->networkx[default]>=2.6->pytextrank) (1.17.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (1.0.15)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (2.0.13)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (3.0.12)
# Requirement already satisfied: thinc<8.4.0,>=8.3.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (8.3.10)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (1.1.3)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (2.5.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (2.0.10)
# Requirement already satisfied: weasel<0.5.0,>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (0.4.3)
# Requirement already satisfied: typer-slim<1.0.0,>=0.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (0.21.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (4.67.1)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (2.32.5)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (2.12.5)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (3.1.6)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from spacy>=3.0->pytextrank) (80.9.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0->pytextrank) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0->pytextrank) (2.41.5)
# Requirement already satisfied: typing-extensions>=4.14.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0->pytextrank) (4.15.0)
# Requirement already satisfied: typing-inspection>=0.4.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy>=3.0->pytextrank) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests<3.0.0,>=2.13.0->spacy>=3.0->pytextrank) (2025.11.12)
# Requirement already satisfied: blis<1.4.0,>=1.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.0->pytextrank) (1.3.3)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from thinc<8.4.0,>=8.3.4->spacy>=3.0->pytextrank) (0.1.5)
# Requirement already satisfied: click>=8.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from typer-slim<1.0.0,>=0.3.0->spacy>=3.0->pytextrank) (8.3.1)
# Requirement already satisfied: cloudpathlib<1.0.0,>=0.7.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from weasel<0.5.0,>=0.4.2->spacy>=3.0->pytextrank) (0.23.0)
# Requirement already satisfied: smart-open<8.0.0,>=5.2.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from weasel<0.5.0,>=0.4.2->spacy>=3.0->pytextrank) (7.5.0)
# Requirement already satisfied: wrapt in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from smart-open<8.0.0,>=5.2.1->weasel<0.5.0,>=0.4.2->spacy>=3.0->pytextrank) (2.0.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jinja2->spacy>=3.0->pytextrank) (3.0.3)
# Downloading pytextrank-3.3.0-py3-none-any.whl (26 kB)
# Downloading graphviz-0.21-py3-none-any.whl (47 kB)
# Downloading icecream-2.1.10-py3-none-any.whl (16 kB)
# Installing collected packages: icecream, graphviz, pytextrank
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [pytextrank]
# Successfully installed graphviz-0.21 icecream-2.1.10 pytextrank-3.3.0

# %%
import spacy
import pytextrank
from spacy.cli import download

model = "en_core_web_lg"
try:
    nlp = spacy.load(model)
except OSError:
    try:
        download(model)
        nlp = spacy.load(model)
    except Exception:
        model = "en_core_web_sm"
        try:
            nlp = spacy.load(model)
        except OSError:
            download(model)
            nlp = spacy.load(model)

if "textrank" not in nlp.pipe_names:
    nlp.add_pipe("textrank")

example_text = """Deep learning (also known as deep structured learning) is part of a 
broader family of machine learning methods based on artificial neural networks with 
representation learning. Learning can be supervised, semi-supervised or unsupervised. 
Deep-learning architectures such as deep neural networks, deep belief networks, deep reinforcement learning, 
recurrent neural networks and convolutional neural networks have been applied to
fields including computer vision, speech recognition, natural language processing, 
machine translation, bioinformatics, drug design, medical image analysis, material
inspection and board game programs, where they have produced results comparable to 
and in some cases surpassing human expert performance. Artificial neural networks
(ANNs) were inspired by information processing and distributed communication nodes
in biological systems. ANNs have various differences from biological brains. Specifically, 
neural networks tend to be static and symbolic, while the biological brain of most living organisms
is dynamic (plastic) and analogue. The adjective "deep" in deep learning refers to the use of multiple
layers in the network. Early work showed that a linear perceptron cannot be a universal classifier, 
but that a network with a nonpolynomial activation function with one hidden layer of unbounded width can.
Deep learning is a modern variation which is concerned with an unbounded number of layers of bounded size, 
which permits practical application and optimized implementation, while retaining theoretical universality 
under mild conditions. In deep learning the layers are also permitted to be heterogeneous and to deviate widely 
from biologically informed connectionist models, for the sake of efficiency, trainability and understandability, 
whence the structured part."""
print("Original Document Size:", len(example_text))

doc = nlp(example_text)

for sent in doc._.textrank.summary(limit_phrases=2, limit_sentences=2):
    print(sent.text)
    print("Summary Length:", len(sent.text))
# Out:
# Collecting en-core-web-lg==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_lg-3.8.0/en_core_web_lg-3.8.0-py3-none-any.whl (400.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.7/400.7 MB 3.7 MB/s  0:01:360:00:0100:03
# Installing collected packages: en-core-web-lg
# Successfully installed en-core-web-lg-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_lg')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Original Document Size: 1820
# Deep-learning architectures such as deep neural networks, deep belief networks, deep reinforcement learning,
# recurrent neural networks and convolutional neural networks have been applied to
# fields including computer vision, speech recognition, natural language processing,
# machine translation, bioinformatics, drug design, medical image analysis, material
# inspection and board game programs, where they have produced results comparable to
# and in some cases surpassing human expert performance.
# Summary Length: 496
# Specifically,
# neural networks tend to be static and symbolic, while the biological brain of most living organisms
# is dynamic (plastic) and analogue.
# Summary Length: 149

# %%
! pip install git+https://github.com/Lightning-AI/pytorch-lightning
! pip install git+https://github.com/huggingface/transformers
! pip install sentencepiece
! pip install git+https://github.com/stas00/transformers
! pip install pegasus
# Out:
# Collecting git+https://github.com/Lightning-AI/pytorch-lightning
#   Cloning https://github.com/Lightning-AI/pytorch-lightning to /private/var/folders/79/qf4s258d1979pqm6v_z63bmc0000gn/T/pip-req-build-dkmegd6f
#   Running command git clone --filter=blob:none --quiet https://github.com/Lightning-AI/pytorch-lightning /private/var/folders/79/qf4s258d1979pqm6v_z63bmc0000gn/T/pip-req-build-dkmegd6f
#   Resolved https://github.com/Lightning-AI/pytorch-lightning to commit 0a0f0610a4d223a258cd73e65abe852a8f703226
#   Running command git submodule update --init --recursive -q
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: PyYAML<8.0,>5.4 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from lightning==2.6.0) (6.0.3)
# Requirement already satisfied: fsspec<2028.0,>=2022.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning==2.6.0) (2025.10.0)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning==2.6.0)
#   Downloading lightning_utilities-0.15.2-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: packaging<27.0,>=23.0 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from lightning==2.6.0) (25.0)
# Requirement already satisfied: torch<4.0,>=2.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from lightning==2.6.0) (2.2.2)
# Collecting torchmetrics<3.0,>0.7.0 (from lightning==2.6.0)
#   Downloading torchmetrics-1.8.2-py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: tqdm<6.0,>=4.57.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from lightning==2.6.0) (4.67.1)
# Requirement already satisfied: typing-extensions<6.0,>4.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from lightning==2.6.0) (4.15.0)
# Collecting pytorch-lightning (from lightning==2.6.0)
#   Downloading pytorch_lightning-2.6.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from fsspec[http]<2028.0,>=2022.5.0->lightning==2.6.0) (3.13.3)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from lightning-utilities<2.0,>=0.10.0->lightning==2.6.0) (80.9.0)
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch<4.0,>=2.1.0->lightning==2.6.0) (3.20.0)
# Requirement already satisfied: sympy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch<4.0,>=2.1.0->lightning==2.6.0) (1.14.0)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch<4.0,>=2.1.0->lightning==2.6.0) (3.5)
# Requirement already satisfied: jinja2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torch<4.0,>=2.1.0->lightning==2.6.0) (3.1.6)
# Requirement already satisfied: numpy>1.20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from torchmetrics<3.0,>0.7.0->lightning==2.6.0) (1.26.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning==2.6.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning==2.6.0) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning==2.6.0) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning==2.6.0) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning==2.6.0) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning==2.6.0) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning==2.6.0) (1.22.0)
# Requirement already satisfied: idna>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<2028.0,>=2022.5.0->lightning==2.6.0) (3.11)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jinja2->torch<4.0,>=2.1.0->lightning==2.6.0) (3.0.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sympy->torch<4.0,>=2.1.0->lightning==2.6.0) (1.3.0)
# Downloading lightning_utilities-0.15.2-py3-none-any.whl (29 kB)
# Downloading torchmetrics-1.8.2-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 6.1 MB/s  0:00:00 eta 0:00:01
# Downloading pytorch_lightning-2.6.0-py3-none-any.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.5/849.5 kB 1.1 MB/s  0:00:00m eta 0:00:01
# Building wheels for collected packages: lightning
#   Building wheel for lightning (pyproject.toml) ... done
#   Created wheel for lightning: filename=lightning-2.6.0-py3-none-any.whl size=853352 sha256=282f41292da3735a2650cb8907651699decaeb70e50e6b5f930169c66e5200e4
#   Stored in directory: /private/var/folders/79/qf4s258d1979pqm6v_z63bmc0000gn/T/pip-ephem-wheel-cache-tfj43fol/wheels/10/7f/31/2aea3a0403c80c91f7ca24b79d3ad7e939f9233c38216b54d6
# Successfully built lightning
# Installing collected packages: lightning-utilities, torchmetrics, pytorch-lightning, lightning
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [lightning]/4 [lightning]ghtning]
# Successfully installed lightning-2.6.0 lightning-utilities-0.15.2 pytorch-lightning-2.6.0 torchmetrics-1.8.2
# Collecting git+https://github.com/huggingface/transformers
#   Cloning https://github.com/huggingface/transformers to /private/var/folders/79/qf4s258d1979pqm6v_z63bmc0000gn/T/pip-req-build-gkbb30ml
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers /private/var/folders/79/qf4s258d1979pqm6v_z63bmc0000gn/T/pip-req-build-gkbb30ml
#   Resolved https://github.com/huggingface/transformers to commit be0115e42fbf5d7ffe915e01b0cf9a68b29958c6
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers==5.0.1.dev0) (3.20.0)
# Collecting huggingface-hub<2.0,>=1.3.0 (from transformers==5.0.1.dev0)
#   Downloading huggingface_hub-1.3.4-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers==5.0.1.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from transformers==5.0.1.dev0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from transformers==5.0.1.dev0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from transformers==5.0.1.dev0) (2025.11.3)
# Collecting tokenizers<=0.23.0,>=0.22.0 (from transformers==5.0.1.dev0)
#   Using cached tokenizers-0.22.2-cp39-abi3-macosx_10_12_x86_64.whl.metadata (7.3 kB)
# Requirement already satisfied: typer-slim in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers==5.0.1.dev0) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from transformers==5.0.1.dev0) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers==5.0.1.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (0.28.1)
# Requirement already satisfied: shellingham in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (1.5.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (4.15.0)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (4.12.1)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (1.0.9)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (3.11)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers==5.0.1.dev0) (0.16.0)
# Requirement already satisfied: click>=8.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from typer-slim->transformers==5.0.1.dev0) (8.3.1)
# Downloading huggingface_hub-1.3.4-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.6/536.6 kB 4.1 MB/s  0:00:00
# Using cached tokenizers-0.22.2-cp39-abi3-macosx_10_12_x86_64.whl (3.1 MB)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-5.0.1.dev0-py3-none-any.whl size=11212445 sha256=3319cf0f15c705374c710350bb380bb2a8b20bbd1f9fc62bf588992e7b9dffa0
#   Stored in directory: /private/var/folders/79/qf4s258d1979pqm6v_z63bmc0000gn/T/pip-ephem-wheel-cache-7vkjo7er/wheels/49/a7/50/c9fdabbf10e51bb1256adb0c1a587fedd7184f5bad28d47fe3
# Successfully built transformers
# Installing collected packages: huggingface-hub, tokenizers, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.36.0
#     Uninstalling huggingface-hub-0.36.0:
#       Successfully uninstalled huggingface-hub-0.36.0
#   Attempting uninstall: tokenizers━━━━━━━━━━━━━━ 0/3 [huggingface-hub]
#     Found existing installation: tokenizers 0.21.40/3 [huggingface-hub]
#     Uninstalling tokenizers-0.21.4:━━━━━━━━━ 0/3 [huggingface-hub]
#       Successfully uninstalled tokenizers-0.21.4 0/3 [huggingface-hub]
#   Attempting uninstall: transformers━━━━━━━━━━━━━━━━━━━━━━━━━━ 1/3 [tokenizers]
#     Found existing installation: transformers 4.49.0━━━━━━━━━━ 1/3 [tokenizers]
#     Uninstalling transformers-4.49.0:m╸━━━━━━━━━━━━━ 2/3 [transformers]
#       Successfully uninstalled transformers-4.49.0━━━━━━━━━━━━ 2/3 [transformers]
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [transformers] [transformers]
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy-transformers 1.3.9 requires transformers<4.50.0,>=3.4.0, but you have transformers 5.0.1.dev0 which is incompatible.
# Successfully installed huggingface-hub-1.3.4 tokenizers-0.22.2 transformers-5.0.1.dev0
# Requirement already satisfied: sentencepiece in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (0.2.1)
# Collecting git+https://github.com/stas00/transformers
#   Cloning https://github.com/stas00/transformers to /private/var/folders/79/qf4s258d1979pqm6v_z63bmc0000gn/T/pip-req-build-dk6p18gf
#   Running command git clone --filter=blob:none --quiet https://github.com/stas00/transformers /private/var/folders/79/qf4s258d1979pqm6v_z63bmc0000gn/T/pip-req-build-dk6p18gf
#   Resolved https://github.com/stas00/transformers to commit 266d3b05684ed5968c613f00b208909f03c72c0e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers==5.0.0.dev0) (3.20.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers==5.0.0.dev0) (1.3.4)
# Requirement already satisfied: numpy>=1.17 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers==5.0.0.dev0) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from transformers==5.0.0.dev0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from transformers==5.0.0.dev0) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from transformers==5.0.0.dev0) (2025.11.3)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers==5.0.0.dev0) (2.32.5)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers==5.0.0.dev0) (0.22.2)
# Requirement already satisfied: typer-slim in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers==5.0.0.dev0) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from transformers==5.0.0.dev0) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from transformers==5.0.0.dev0) (4.67.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.0.0->transformers==5.0.0.dev0) (2025.10.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /Users/imac/Library/Python/3.12/lib/python/site-packages (from huggingface-hub<2.0,>=1.0.0->transformers==5.0.0.dev0) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.0.0->transformers==5.0.0.dev0) (0.28.1)
# Requirement already satisfied: shellingham in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.0.0->transformers==5.0.0.dev0) (1.5.4)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from huggingface-hub<2.0,>=1.0.0->transformers==5.0.0.dev0) (4.15.0)
# Requirement already satisfied: anyio in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.0.0->transformers==5.0.0.dev0) (4.12.1)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.0.0->transformers==5.0.0.dev0) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.0.0->transformers==5.0.0.dev0) (1.0.9)
# Requirement already satisfied: idna in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.0.0->transformers==5.0.0.dev0) (3.11)
# Requirement already satisfied: h11>=0.16 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.0.0->transformers==5.0.0.dev0) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->transformers==5.0.0.dev0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->transformers==5.0.0.dev0) (2.5.0)
# Requirement already satisfied: click>=8.0.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from typer-slim->transformers==5.0.0.dev0) (8.3.1)
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-5.0.0.dev0-py3-none-any.whl size=11379557 sha256=15d504d97a634e6e93dec817c7b553b4e1695f6576381a762e3d56d8e719b57e
#   Stored in directory: /private/var/folders/79/qf4s258d1979pqm6v_z63bmc0000gn/T/pip-ephem-wheel-cache-unanf7mb/wheels/b6/11/e9/3ce941d24f4c166c7522f096d6e1629134e10dca170a0c1ac4
# Successfully built transformers
# Installing collected packages: transformers
#   Attempting uninstall: transformers
#     Found existing installation: transformers 5.0.1.dev0
#     Uninstalling transformers-5.0.1.dev0:
#       Successfully uninstalled transformers-5.0.1.dev0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# spacy-transformers 1.3.9 requires transformers<4.50.0,>=3.4.0, but you have transformers 5.0.0.dev0 which is incompatible.
# Successfully installed transformers-5.0.0.dev0
# Collecting pegasus
#   Downloading pegasus-0.1.3.tar.gz (8.7 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pegasus
#   Building wheel for pegasus (pyproject.toml) ... done
#   Created wheel for pegasus: filename=pegasus-0.1.3-py3-none-any.whl size=6507 sha256=a506c8c8d7be222e19434e0266091c2540aba29121ebd02efee265ee0722ac06
#   Stored in directory: /Users/imac/Library/Caches/pip/wheels/71/aa/30/5b87d42deedc4dc8aa4487999831883e24741e1eb47bcc0f64
# Successfully built pegasus
# Installing collected packages: pegasus
# Successfully installed pegasus-0.1.3

# %%
from transformers import PegasusForConditionalGeneration, PegasusTokenizer
from transformers import pipeline

model_name = "google/pegasus-xsum"
pegasus_tokenizer = PegasusTokenizer.from_pretrained(model_name)
example_text="""
deep learning (also known as deep structured learning) is part of a 
broader family of machine learning methods based on artificial neural networks with 
representation learning. Learning can be supervised, semi-supervised or unsupervised. 
Deep-learning architectures such as deep neural networks, deep belief networks, deep reinforcement learning, 
recurrent neural networks and convolutional neural networks have been applied to
fields including computer vision, speech recognition, natural language processing, 
machine translation, bioinformatics, drug design, medical image analysis, material
inspection and board game programs, where they have produced results comparable to 
and in some cases surpassing human expert performance. Artificial neural networks
(ANNs) were inspired by information processing and distributed communication nodes
in biological systems. ANNs have various differences from biological brains. Specifically, 
neural networks tend to be static and symbolic, while the biological brain of most living organisms
is dynamic (plastic) and analogue. The adjective "deep" in deep learning refers to the use of multiple
layers in the network. Early work showed that a linear perceptron cannot be a universal classifier, 
but that a network with a nonpolynomial activation function with one hidden layer of unbounded width can.
Deep learning is a modern variation which is concerned with an unbounded number of layers of bounded size, 
which permits practical application and optimized implementation, while retaining theoretical universality 
under mild conditions. In deep learning the layers are also permitted to be heterogeneous and to deviate widely 
from biologically informed connectionist models, for the sake of efficiency, trainability and understandability, 
whence the structured par








"""




print("Original Document Size:", len(example_text))
pegasus_model = PegasusForConditionalGeneration.from_pretrained(model_name)
tokens=pegasus_tokenizer(example_text, truncation=True, padding="longest", return_tensors="pt")
summary = pegasus_model.generate(**tokens)
decoded_summary = pegasus_tokenizer.decode(summary[0], skip_special_tokens=True)
print("Summary Size:", len(decoded_summary))
summarizer=pipeline(
    "summarization",
    model="google/pegasus-xsum",
    tokenizer="google/pegasus-xsum",
    framework="pt"
)
summary=summarizer(example_text, max_length=60, min_length=20, do_sample=False)
summary[0]['summary_text']
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/utils/import_utils.py:1863, in _get_module(self, module_name)
#    1862 for key, values in module.items():
# -> 1863     if missing_backends:
#    1864         self._object_missing_backend[key] = missing_backends
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/importlib/__init__.py:90, in import_module(name, package)
#      89         level += 1
# ---> 90 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1381, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1354, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1325, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:929, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:994, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/models/pegasus/modeling_pegasus.py:28
#      27 from ... import initialization as init
# ---> 28 from ...activations import ACT2FN
#      29 from ...cache_utils import Cache, DynamicCache, EncoderDecoderCache
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/activations.py:22
#      20 from torch import Tensor, nn
# ---> 22 from .integrations.hub_kernels import use_kernel_forward_from_hub
#      23 from .utils import logging
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/integrations/hub_kernels.py:21
#      19 from typing import Optional, Union
# ---> 21 from ..modeling_flash_attention_utils import lazy_import_flash_attention
#      22 from ..utils import ENV_VARS_TRUE_VALUES, logging
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/modeling_flash_attention_utils.py:22
#      20 import torch.nn.functional as F
# ---> 22 from .utils import (
#      23     is_flash_attn_2_available,
#      24     is_flash_attn_3_available,
#      25     is_flash_attn_greater_or_equal_2_10,
#      26     is_torch_npu_available,
#      27     logging,
#      28 )
#      31 logger = logging.get_logger(__name__)
#
# ImportError: cannot import name 'is_flash_attn_3_available' from 'transformers.utils' (/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/utils/__init__.py)
#
# The above exception was the direct cause of the following exception:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from transformers import PegasusForConditionalGeneration, PegasusTokenizer
#       2 from transformers import pipeline
#       4 model_name = "google/pegasus-xsum"
#
# File <frozen importlib._bootstrap>:1406, in _handle_fromlist(module, fromlist, import_, recursive)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/utils/import_utils.py:1852, in __getattr__(self, name)
#    1848         callable = backend.is_satisfied
#    1849     else:
#    1850         raise ValueError(
#    1851             f"Backend should be defined in the BACKENDS_MAPPING. Offending backend: {backend}"
# -> 1852         )
#    1854 try:
#    1855     if not callable():
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/utils/import_utils.py:1851, in __getattr__(self, name)
#    1848         callable = backend.is_satisfied
#    1849     else:
#    1850         raise ValueError(
# -> 1851             f"Backend should be defined in the BACKENDS_MAPPING. Offending backend: {backend}"
#    1852         )
#    1854 try:
#    1855     if not callable():
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/utils/import_utils.py:1865, in _get_module(self, module_name)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# RuntimeError: Failed to import transformers.models.pegasus.modeling_pegasus because of the following error (look up to see its traceback):
# cannot import name 'is_flash_attn_3_available' from 'transformers.utils' (/Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/transformers/utils/__init__.py)
