# %%
! pip install transformers torch T5ForConditionalGeneration
# Out:
# ...
# ERROR: Could not find a version that satisfies the requirement T5ForConditionalGeneration (from versions: none)
# ERROR: No matching distribution found for T5ForConditionalGeneration
